# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Mar  3 13:19:09 2022

@author: Sjoerd Quaak

The aim of this script is to read the HIS files, play the movie and make an intensity plot
"""

#####

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.animation import FFMpegWriter
from readHISbasic import readSection
no = 24
filedir = 'D:\\20220405\\'
fn = filedir + 'C'+str(no).zfill(5)+'.his'
# fn = r'C:\Users\brugg\Documents\MasterThesis\01062022\20000007.HIS'
fn = r'D:\Ingmar\Ingmar\HisFiles\20000029.HIS'

nframes = 2000

#%%

#First, lets plot a single frame
m = np.memmap(fn, shape=None, mode = 'r')
offset = 0
img = readSection(m, offset)
plt.figure()

imgplot = plt.imshow(img)


#%%
#Now, let's make a movie dataset
movie = np.zeros((nframes,img.shape[0],img.shape[1]), dtype=np.uint16)
m = np.memmap(fn, shape=None, mode = 'r')
print(m.shape)

offset = 0 

offsets = []
for i in range(0,600):
    offsets.append(offset)
    
    frame = readSection(m, offset)
    
    temp = np.copy(frame)
    print(i, offset, temp.shape)
   
    movie[i] = np.copy(frame)
    offset = frame.HIS.offsetNext
    
 #Set values below a certain treshold to zero      
#movie[movie<450] = 0

    
#%%
#Tweak the last numbers to cut off more or less from the image, to get to the region of interest
#the first frame (called img) is used for this
    

border_ver1 =0 + 15
border_ver2 = img.shape[0] - 15
border_hor1 = 0 + 00
border_hor2 = img.shape[1]-100


h = img.shape[0]
w = img.shape[1]



img_cut = img[border_ver1:border_ver2,border_hor1:border_hor2]
plt.figure()
imgcutplot = plt.imshow(img_cut)



#%%
#Play the movie as an animation
#Call the function in the console
def execute_movie():
    fig = plt.figure()
    axis = plt.axes()
    
    film = plt.imshow(movie[0])
    
    def init(): 
        film.set_data(movie[0])
        return [film]
    
    
    def animate(i):
        film.set_array(movie[i])
        return [film]
    fig.suptitle('Measurement '+str(no))
    
    anim = FuncAnimation(fig, animate, init_func = init, 
                         frames = nframes, interval = 20, blit = True)

    return anim


#%%



#Or play the movie with the borders cut:
#Call the function in the console
def execute_movie_cut():

    fig = plt.figure()  
    axis = plt.axes()

    film = plt.imshow(movie[0][border_ver1:border_ver2,border_hor1:border_hor2])

    def init(): 
        film.set_data(movie[0][border_ver1:border_ver2,border_hor1:border_hor2])
        return [film]

    def animate(i):
        film.set_array(movie[i][border_ver1:border_ver2,border_hor1:border_hor2])
        return [film]
    
    fig.suptitle('Measurement cut '+str(no))
   
    
    anim = FuncAnimation(fig, animate, init_func = init,
                         frames = nframes, interval = 20, blit = True)

    
    return anim

execute_movie()

#%%

plt.figure(figsize=(10,10))
im=plt.imshow(movie[0, :,:])
plt.colorbar()
every_Nth_frame = 1
for i in np.arange(1, movie.shape[0], every_Nth_frame):
    im.set_data(movie[i, :,:])
    plt.title(f'{i/20} s')
    plt.pause(1./1000000)
    #plt.savefig(f"D:\Anna\\20220703\Video_bg\Landing_Au_100nm_bgcorrected__{i:04}.jpeg")
plt.show()
#%%

#plt.close('all')  
intensity = np.zeros(len(movie))
minute_list = np.linspace(0,60,len(movie))

for i in range(nframes):
    intensity[i] = sum(sum(movie[i][border_ver1:border_ver2,border_hor1:border_hor2]))
I=intensity/1000    
plt.figure()
plt.plot(minute_list, I, label = no)
plt.xlabel("Time (s)", fontsize=18)
plt.xlim(0,60)
plt.ylabel("Integrated Intensity (a.u.)", fontsize=18)
plt.suptitle(str(no))
plt.savefig('Intensity Measurement - number: '+str(no)+'.png')
np.savetxt('intensity'+str(no)+'.csv', intensity, delimiter=',')

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.animation import FFMpegWriter
from readHISbasic import readSection
no = 24
filedir = 'D:\\20220405\\'
fn = filedir + 'C'+str(no).zfill(5)+'.his'
# fn = r'C:\Users\brugg\Documents\MasterThesis\01062022\20000007.HIS'
fn = r'D:\Ingmar\Ingmar\HisFiles\20000030.HIS'

nframes = 2000

#%%

#First, lets plot a single frame
m = np.memmap(fn, shape=None, mode = 'r')
n = np.array(fn)
offset = 0
img = readSection(m, offset)
# plt.figure()

# imgplot = plt.imshow(img)

print(m.size)

# %%
2048*2048*500*2

# %%
#####

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.animation import FFMpegWriter
from readHISbasic import readSection
import readHISbasic as RHIS
no = 24
filedir = 'D:\\20220405\\'
fn = filedir + 'C'+str(no).zfill(5)+'.his'
# fn = r'C:\Users\brugg\Documents\MasterThesis\01062022\20000007.HIS'
fn = r'D:\Ingmar\Ingmar\HisFiles\20000029.HIS'

nframes = 500

#%%

#First, lets plot a single frame
m = np.memmap(fn, shape=None, mode = 'r')
offset = 0
img = RHIS.readSection(m, offset)
plt.figure()

# imgplot = plt.imshow(img)


#%%
#Now, let's make a movie dataset
movie = np.zeros((nframes,img.shape[0],img.shape[1]), dtype=np.uint16)
m = np.memmap(fn, shape=(2048*2048*2*290,), mode = 'r')
# print(m.shape)

offset = 0 

offsets = []
for i in range(nframes):
    offsets.append(offset)
    
    frame = RHIS.readSection(m, offset)
    
    temp = np.copy(frame)
    print(i, offset, temp.shape)
   
    movie[i] = np.copy(frame)
    offset = frame.HIS.offsetNext
# Out:
# 0 0 (2048, 2048)
# 1 8389250 (2048, 2048)
# 2 16778278 (2048, 2048)
# 3 25167306 (2048, 2048)
# 4 33556334 (2048, 2048)
# 5 41945362 (2048, 2048)
# 6 50334390 (2048, 2048)
# 7 58723418 (2048, 2048)
# 8 67112446 (2048, 2048)
# 9 75501474 (2048, 2048)
# 10 83890502 (2048, 2048)
# 11 92279530 (2048, 2048)
# 12 100668558 (2048, 2048)
# 13 109057586 (2048, 2048)
# 14 117446614 (2048, 2048)
# 15 125835642 (2048, 2048)
# 16 134224670 (2048, 2048)
# 17 142613698 (2048, 2048)
# 18 151002726 (2048, 2048)
# 19 159391754 (2048, 2048)
# 20 167780782 (2048, 2048)
# 21 176169810 (2048, 2048)
# 22 184558838 (2048, 2048)
# 23 192947866 (2048, 2048)
# 24 201336894 (2048, 2048)
# 25 209725922 (2048, 2048)
# 26 218114950 (2048, 2048)
# 196 1644250002 (2048, 2048)
# 197 1652639032 (2048, 2048)
# 198 1661028062 (2048, 2048)
# 199 1669417092 (2048, 2048)
# 200 1677806122 (2048, 2048)
# 201 1686195152 (2048, 2048)
# 202 1694584182 (2048, 2048)
# 203 1702973212 (2048, 2048)
# 204 1711362242 (2048, 2048)
# 205 1719751272 (2048, 2048)
# 206 1728140302 (2048, 2048)
# 207 1736529332 (2048, 2048)
# 208 1744918362 (2048, 2048)
# 209 1753307392 (2048, 2048)
# 210 1761696422 (2048, 2048)
# 211 1770085452 (2048, 2048)
# 212 1778474482 (2048, 2048)
# 213 1786863512 (2048, 2048)
# 214 1795252542 (2048, 2048)
# 215 1803641572 (2048, 2048)
# 216 1812030602 (2048, 2048)
# 217 1820419632 (2048, 2048)
# 218 1828808662 (2048, 2048)
# 219 1837197692 (2048, 2048)
# 220 1845586722 (2048, 2048)
# 221 1853975752 (2048, 2048)
# 222 1862364782 (2048, 2048)
# 223 1870753812 (2048, 2048)
# 224 1879142842 (2048, 2048)
# 225 1887531872 (2048, 2048)
# 226 1895920902 (2048, 2048)
# 227 1904309932 (2048, 2048)
# 228 1912698962 (2048, 2048)
# 229 1921087992 (2048, 2048)
# 230 1929477022 (2048, 2048)
# 231 1937866052 (2048, 2048)
# 232 1946255082 (2048, 2048)
# 233 1954644112 (2048, 2048)
# 234 1963033142 (2048, 2048)
# 235 1971422172 (2048, 2048)
# 236 1979811202 (2048, 2048)
# 237 1988200232 (2048, 2048)
# 238 1996589262 (2048, 2048)
# 239 2004978292 (2048, 2048)
# 240 2013367322 (2048, 2048)
# 241 2021756352 (2048, 2048)
# 242 2030145382 (2048, 2048)
# 243 2038534412 (2048, 2048)
# 244 2046923442 (2048, 2048)
# 245 2055312472 (2048, 2048)
# 246 2063701502 (2048, 2048)
# 247 2072090532 (2048, 2048)
# 248 2080479562 (2048, 2048)
# 249 2088868592 (2048, 2048)
# 250 2097257622 (2048, 2048)
# 251 2105646652 (2048, 2048)
# 252 2114035682 (2048, 2048)
# 253 2122424712 (2048, 2048)
# 254 2130813742 (2048, 2048)
# C:\Users\brugg\PycharmProjects\epicsjukebox\Notebooks\Ingmar\readHISbasic.py:125: RuntimeWarning: overflow encountered in long_scalars
#   sectEnd = offsetImg + imgBytes
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-e2632a8f5387> in <module>
#      38     offsets.append(offset)
#      39
# ---> 40     frame = RHIS.readSection(m, offset)
#      41
#      42     temp = np.copy(frame)
#
# ~\PycharmProjects\epicsjukebox\Notebooks\Ingmar\readHISbasic.py in readSection(m, offsetSect)
#     127     img = m[offsetImg:sectEnd]
#     128     img.dtype = imgPixDType
# --> 129     img.shape = hisHdr['iDY'], hisHdr['iDX']
#     130
#     131     class hisHeaderInfo:
#
# ValueError: cannot reshape array of size 0 into shape (2048,2048)

# %%
m.shape

# %%
int(m.shape[0])-1669417096

# %%
2**8

# %%
2048*2048*2*600

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import time

from Particledrop import Landing_Flashes

import trackpy

np.random.seed(31415)
plt.close('all')

nf = 50
fov=[200,300]
meas = Landing_Flashes(fov=fov, seed=500, numpar = 30, noise = 0, nframes = nf, signal = 20, sizevar=0.2, dark = 5, psize = 4, unevenIllumination = False)
plis = meas.parlist
movie = meas.genStack()
print(np.shape(plis))
# Out:
# (29, 3)

# %%
plt.figure()
plt.title('Simulated Size histogram')
plt.hist(plis[:,2])
plt.show()

# %%
testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

# %%
meas.noise = 1 
plis = meas.parlist
movie = meas.genStack()

testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

# %%
meas.noise = 2 
plis = meas.parlist
movie = meas.genStack()

testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

# %%
img = movie[testframe]
imglist = img.flatten()

fig, ax = plt.subplots()
plt.title('Intensities in last frame')
ax.hist(imglist, bins = 30)
# Out:
# (array([7.8340e+03, 1.5696e+04, 1.5745e+04, 1.0562e+04, 5.2720e+03,
#         2.0780e+03, 6.9400e+02, 2.1000e+02, 9.0000e+01, 1.0100e+02,
#         1.5100e+02, 2.0600e+02, 2.5100e+02, 1.8000e+02, 1.8000e+02,
#         1.6000e+02, 1.1800e+02, 8.6000e+01, 1.0000e+02, 7.7000e+01,
#         4.4000e+01, 4.3000e+01, 2.8000e+01, 3.0000e+01, 2.2000e+01,
#         2.3000e+01, 1.0000e+01, 7.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([ 5.        ,  5.93057421,  6.86114842,  7.79172264,  8.72229685,
#          9.65287106, 10.58344527, 11.51401948, 12.4445937 , 13.37516791,
#         14.30574212, 15.23631633, 16.16689054, 17.09746476, 18.02803897,
#         18.95861318, 19.88918739, 20.8197616 , 21.75033582, 22.68091003,
#         23.61148424, 24.54205845, 25.47263266, 26.40320688, 27.33378109,
#         28.2643553 , 29.19492951, 30.12550372, 31.05607794, 31.98665215,
#         32.91722636]),
#  <a list of 30 Patch objects>)

# %%
cutoff = 13 

movie_cutoff = np.where(movie < cutoff, 0, movie)
img_co = movie_cutoff[testframe]

plt.figure()
plt.imshow(img_co)

f = trackpy.locate(movie_cutoff[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie_cutoff[testframe]);

# %%
meas.noise = 5 
plis = meas.parlist
movie = meas.genStack()

testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

# %%
img = movie[testframe]
imglist = img.flatten()

fig, ax = plt.subplots()
plt.title('Intensities in last frame')
ax.hist(imglist, bins = 30)
# Out:
# (array([2.3590e+03, 4.9400e+03, 8.1720e+03, 1.0171e+04, 1.0159e+04,
#         8.4550e+03, 6.1050e+03, 3.7840e+03, 2.1810e+03, 1.0730e+03,
#         8.2500e+02, 2.2800e+02, 2.2900e+02, 2.3700e+02, 1.9800e+02,
#         1.8600e+02, 1.5800e+02, 1.3100e+02, 1.0900e+02, 7.7000e+01,
#         5.7000e+01, 5.2000e+01, 4.3000e+01, 2.9000e+01, 1.3000e+01,
#         1.2000e+01, 9.0000e+00, 7.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([ 5.        ,  6.09724088,  7.19448176,  8.29172264,  9.38896351,
#         10.48620439, 11.58344527, 12.68068615, 13.77792703, 14.87516791,
#         15.97240879, 17.06964967, 18.16689054, 19.26413142, 20.3613723 ,
#         21.45861318, 22.55585406, 23.65309494, 24.75033582, 25.84757669,
#         26.94481757, 28.04205845, 29.13929933, 30.23654021, 31.33378109,
#         32.43102197, 33.52826284, 34.62550372, 35.7227446 , 36.81998548,
#         37.91722636]),
#  <a list of 30 Patch objects>)

# %%
cutoff = 23

movie_cutoff = np.where(movie < cutoff, 0, movie)
img_co = movie_cutoff[testframe]

plt.figure()
plt.imshow(img_co)

f = trackpy.locate(movie_cutoff[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie_cutoff[testframe]);

# %%
meas.noise = 10 
plis = meas.parlist
movie = meas.genStack()

testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);
# Out:
# C:\Users\sjoer\Anaconda3\lib\site-packages\trackpy\uncertainty.py:49: RuntimeWarning: divide by zero encountered in true_divide
#   N_S = noise / mass

# %%
img = movie[testframe]
imglist = img.flatten()

fig, ax = plt.subplots()
plt.title('Intensities in last frame')
ax.hist(imglist, bins = 30)
# Out:
# (array([3.5000e+01, 1.4300e+02, 4.0700e+02, 3.3070e+03, 3.5960e+03,
#         5.2030e+03, 1.3911e+04, 7.4180e+03, 6.6910e+03, 9.6310e+03,
#         3.0090e+03, 2.0860e+03, 1.4450e+03, 1.3290e+03, 4.3100e+02,
#         3.2700e+02, 2.6500e+02, 1.7400e+02, 1.5000e+02, 1.4100e+02,
#         8.0000e+01, 7.2000e+01, 4.8000e+01, 3.8000e+01, 1.6000e+01,
#         2.3000e+01, 1.0000e+01, 6.0000e+00, 5.0000e+00, 3.0000e+00]),
#  array([ 5.        ,  6.3066194 ,  7.61323881,  8.91985821, 10.22647762,
#         11.53309702, 12.83971643, 14.14633583, 15.45295524, 16.75957464,
#         18.06619405, 19.37281345, 20.67943286, 21.98605226, 23.29267167,
#         24.59929107, 25.90591048, 27.21252988, 28.51914929, 29.82576869,
#         31.1323881 , 32.4390075 , 33.74562691, 35.05224631, 36.35886572,
#         37.66548512, 38.97210453, 40.27872393, 41.58534334, 42.89196274,
#         44.19858215]),
#  <a list of 30 Patch objects>)

# %%
cutoff = 30

movie_cutoff = np.where(movie < cutoff, 0, movie)
img_co = movie_cutoff[testframe]

plt.figure()
plt.imshow(img_co)

f = trackpy.locate(movie_cutoff[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie_cutoff[testframe]);

# %%
meas.noise = 20 
plis = meas.parlist
movie = meas.genStack()

testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

# %%
img = movie[testframe]
imglist = img.flatten()

fig, ax = plt.subplots()
plt.title('Intensities in last frame')
ax.hist(imglist, bins = 30)
# Out:
# (array([2.0000e+00, 1.6000e+01, 1.0100e+02, 4.8800e+02, 5.6400e+02,
#         2.5970e+03, 5.2150e+03, 8.2650e+03, 4.9760e+03, 1.0149e+04,
#         9.4890e+03, 7.2790e+03, 2.7130e+03, 3.7720e+03, 1.9790e+03,
#         1.0180e+03, 5.1300e+02, 2.7100e+02, 2.2500e+02, 1.2800e+02,
#         1.0700e+02, 5.4000e+01, 3.7000e+01, 2.3000e+01, 8.0000e+00,
#         2.0000e+00, 4.0000e+00, 3.0000e+00, 1.0000e+00, 1.0000e+00]),
#  array([ 8.        ,  9.76532334, 11.53064667, 13.29597001, 15.06129335,
#         16.82661668, 18.59194002, 20.35726336, 22.12258669, 23.88791003,
#         25.65323337, 27.4185567 , 29.18388004, 30.94920338, 32.71452671,
#         34.47985005, 36.24517339, 38.01049672, 39.77582006, 41.5411434 ,
#         43.30646673, 45.07179007, 46.83711341, 48.60243674, 50.36776008,
#         52.13308342, 53.89840675, 55.66373009, 57.42905343, 59.19437676,
#         60.9597001 ]),
#  <a list of 30 Patch objects>)

# %%
cutoff = 45

movie_cutoff = np.where(movie < cutoff, 0, movie)
img_co = movie_cutoff[testframe]

plt.figure()
plt.imshow(img_co)

f = trackpy.locate(movie_cutoff[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie_cutoff[testframe]);

# %%
meas.noise = 20
plis = meas.parlist
movie = meas.genStack()
img = movie[testframe]

plt.figure()
plt.imshow(img)

# %%
from scipy import fftpack
im_fft = fftpack.fft2(img)

# Show the results

def plot_spectrum(im_fft):
    from matplotlib.colors import LogNorm
    # A logarithmic colormap
    plt.imshow(np.abs(im_fft), norm=LogNorm(vmin=5))
    plt.colorbar()

plt.figure()
plot_spectrum(im_fft)
plt.title('Fourier transform')
# Out:
# C:\Users\sjoer\Anaconda3\lib\site-packages\scipy\fftpack\basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x
# Text(0.5,1,'Fourier transform')

# %%
meas.noise = 20
plis = meas.parlist
movie = meas.genStack()
img = movie[testframe]

plt.figure()
plt.imshow(img)

# %%
from scipy import fftpack
im_fft = fftpack.fft2(img)

# Show the results

def plot_spectrum(im_fft):
    from matplotlib.colors import LogNorm
    # A logarithmic colormap
    plt.imshow(np.abs(im_fft), norm=LogNorm(vmin=5))
    plt.colorbar()

plt.figure()
plot_spectrum(im_fft)
plt.title('Fourier transform')
# Out:
# C:\Users\sjoer\Anaconda3\lib\site-packages\scipy\fftpack\basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x
# Text(0.5,1,'Fourier transform')

# %% [markdown]
# The corners contain the real info (particles), the rest is noise. How to compare to particle size?

# %%
# In the lines following, we'll make a copy of the original spectrum and
# truncate coefficients.

# Define the fraction of coefficients (in each direction) we keep
keep_fraction = 0.05

# Call ff a copy of the original transform. Numpy arrays have a copy
# method for this purpose.
im_fft2 = im_fft.copy()

# Set r and c to be the number of rows and columns of the array.
r, c = im_fft2.shape

# Set to zero all rows with indices between r*keep_fraction and
# r*(1-keep_fraction):
im_fft2[int(r*keep_fraction):int(r*(1-keep_fraction))] = 0

# Similarly with the columns:
im_fft2[:, int(c*keep_fraction):int(c*(1-keep_fraction))] = 0

plt.figure()
plot_spectrum(im_fft2)
plt.title('Filtered Spectrum')
# Out:
# Text(0.5,1,'Filtered Spectrum')

# %%
# Reconstruct the denoised image from the filtered spectrum, keep only the
# real part for display.
im_new = fftpack.ifft2(im_fft2).real

plt.figure()
plt.imshow(im_new, plt.cm.gray)
plt.title('Reconstructed Image')
# Out:
# C:\Users\sjoer\Anaconda3\lib\site-packages\scipy\fftpack\basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x
# Text(0.5,1,'Reconstructed Image')

# %%
f = trackpy.locate(im_new, 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, im_new);

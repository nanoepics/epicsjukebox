# %% [markdown]
# In this notebook, I'll look even deeper into the moving average

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation
from matplotlib.animation import FuncAnimation
import time

from Particledrop import Landing_Flashes

import trackpy

# %% [markdown]
# Let's also try to get an animation in the notebook: IT worked! Not sure why it always also plots the last frame, but it does
# This function is now calleable for any movie dataset, so movies or backgroundcorrected movies.

# %%
def execute_amovie(moviedata):
    plt.rcParams["animation.html"] = "jshtml"
    plt.rcParams['figure.dpi'] = 100  
    plt.ioff()
    
    fig = plt.figure()
    axis = plt.axes()
    
    film = plt.imshow(moviedata[0])
    
    def init(): 
        film.set_data(moviedata[0])
        return [film]
    
    def animate(i):
        film.set_array(moviedata[i])
        return [film]
    
    anim = FuncAnimation(fig, animate, frames = moviedata.shape[0], init_func = init, interval = 20, blit = True)

    return anim

# %%
nf = 100
fov=[200,300]
meas = Landing_Flashes(fov=fov, seed=5045, numpar = 50, noise = 0, nframes = nf, signal = 20, sizevar=0.2, dark = 5, psize = 4, unevenIllumination = False)
testframe = nf-1
meas.noise = 0
plis = meas.parlist
movie = meas.genStack()
print(np.shape(plis))

execute_amovie(movie)
# Out:
# (50, 3)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img5ccce8202fc5410f91311acfe2671154">
#     <br>
#     <input id="_anim_slider5ccce8202fc5410f91311acfe2671154" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim5ccce8202fc5410f91311acfe2671154.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim5ccce8202fc5410f91311acfe2671154.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim5ccce8202fc5410f91311acfe2671154.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim5ccce8202fc5410f91311acfe2671154.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim5ccce8202fc5410f91311acfe2671154.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim5ccce8202fc5410f91311acfe2671154.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim5ccce8202fc5410f91311acfe2671154.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim5ccce8202fc5410f91311acfe2671154.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim5ccce8202fc5410f91311acfe2671154.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim5ccce8202fc5410f91311acfe2671154.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select5ccce8202fc5410f91311acfe2671154" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img5ccce8202fc5410f91311acfe2671154";
#     var slider_id = "_anim_slider5ccce8202fc5410f91311acfe2671154";
#     var loop_select_id = "_anim_loop_select5ccce8202fc5410f91311acfe2671154";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAAPYQAAD2EBqD+naQAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvIxREBQAAIABJREFUeJzt3XtwVOX9x/HPQpIVMNkSQrJZCTF1\
# 8EYwGlAuXggq0chFijeEofEyaa2CRmCU1HEMjhq1o21HqrXVUaxYmI4CtlBqUAIyJAoBFPAyQSOg\
# JkSZsBsQNwk8vz/8eWRNAkGfZNnd92vmjDnnec76Pd/Z1U+ePbtxGWOMAAAAYE2PcBcAAAAQbQhY\
# AAAAlhGwAAAALCNgAQAAWEbAAgAAsIyABQAAYBkBCwAAwDICFgAAgGUELAAAAMsIWAAAAJYRsAAA\
# ACwjYAEAAFhGwAIAALCMgAUAAGAZAQsAAMAyAhYAAIBlBCwAAADLCFgAAACWEbAAAAAsI2ABAABY\
# RsACAACwjIAFAABgGQELAADAMgIWAACAZQQsAAAAywhYAAAAlhGwAAAALCNgAQAAWEbAAgAAsIyA\
# BQAAYBkBCwAAwDICFgAAgGUELAAAAMsIWAAAAJYRsAAAACwjYAEAAFhGwAIAALCMgAUAAGAZAQsA\
# AMAyAhYAAIBlBCwAAADLCFgAAACWEbAAAAAsI2BJevrpp5WVlaWTTjpJQ4cO1dtvvx3ukgAAQASL\
# +YC1ePFiFRcX67777tPmzZt18cUXq6CgQLt27Qp3aQAAIEK5jDEm3EWE0/Dhw5Wbm6tnnnnGOXbW\
# WWdp0qRJKisrC2NlAAAgUsWFu4Bwam5uVnV1tebOnRtyPD8/X+vXr+/UYxw+fFhffvmlEhMT5XK5\
# uqJMAAAigjFGTU1N8vl86tEjtt8ki+mA9fXXX+vQoUNKS0sLOZ6Wlqb6+vp2zwkGgwoGg87+F198\
# obPPPrtL6wQAIJLs3r1bAwYMCHcZYRXTAet7P155MsZ0uBpVVlamefPmtTl+ka5SnOK7pD4AACJB\
# q1q0TiuUmJgY7lLCLqYDVkpKinr27NlmtaqhoaHNqtb3SkpKNGvWLGc/EAgoIyNDcYpXnIuABQCI\
# Yf9/Vze3zMT4pwgTEhI0dOhQlZeXhxwvLy/XqFGj2j3H7XYrKSkpZAMAADhSTK9gSdKsWbM0ffp0\
# DRs2TCNHjtTf/vY37dq1S7fddlu4SwMAABEq5gPWDTfcoL179+rBBx9UXV2dsrOztWLFCmVmZoa7\
# NAAAEKFi/nuwfq5AICCPx6M8Xc09WACAmNZqWlShZfL7/TF/C01M34MFAADQFQhYAAAAlhGwAAAA\
# LCNgAQAAWEbAAgAAsIyABQAAYBkBCwAAwDICFgAAgGUELAAAAMsIWAAAAJYRsAAAACwjYAEAAFhG\
# wAIAALCMgAUAAGAZAQsAAMAyAhYAAIBlBCwAAADLCFgAAACWEbAAAAAsI2ABAABYRsACAACwjIAF\
# AABgGQELAADAMgIWAACAZQQsAAAAywhYAAAAlhGwAAAALIvqgFVWVqbzzz9fiYmJSk1N1aRJk/Tx\
# xx+HzMnLy5PL5QrZpkyZEqaKAQBANIjqgLVmzRrdcccdqqqqUnl5uVpbW5Wfn68DBw6EzCsqKlJd\
# XZ2zPfvss2GqGAAARIO4cBfQlVauXBmy/8ILLyg1NVXV1dW65JJLnOO9e/eW1+vt7vIAAECUiuoV\
# rB/z+/2SpOTk5JDjCxcuVEpKigYPHqw5c+aoqakpHOUBAIAoEdUrWEcyxmjWrFm66KKLlJ2d7Ryf\
# Nm2asrKy5PV6tW3bNpWUlOi9995TeXl5u48TDAYVDAad/UAg0OW1AwCAyBIzAWvGjBl6//33tW7d\
# upDjRUVFzs/Z2dkaNGiQhg0bpk2bNik3N7fN45SVlWnevHldXi8AAIhcMfEW4cyZM/X6669r9erV\
# GjBgwFHn5ubmKj4+XjU1Ne2Ol5SUyO/3O9vu3bu7omQAABDBonoFyxijmTNnasmSJ

# %% [markdown]
# With these settings, trackpy finds the particles pretty good, but doesn't find doubles. Let's see if a moving average can change that.

# %%
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

print(len(f['mass']))
# Out:
# 45

# %% [markdown]
# How does trackpy batch work? How do you see how many particles it has found?

# %%
f_2 = trackpy.batch(movie[:,:,:], 7, minmass=10, invert=False, processes='auto')
print(len(f_2['mass']))
# Out:
# Frame 99: 45 features
# 2728

# %%
def BGCMovingAverage(movie):
    start = 6
    end = nf

    BGCma = movie[start:end,:,:] - np.mean([movie[start-5:end-5,:,:],
                                          movie[start-4:end-4,:,:],
                                          movie[start-3:end-3,:,:],
                                          movie[start-2:end-2,:,:],
                                          movie[start-1:end-1,:,:]],
                                          axis = 0)
    #Normalization could be important
    BGCma2 = BGCma/movie[0]
    return BGCma2

BGCMA = BGCMovingAverage(movie)
execute_amovie(BGCMA)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img
# AQsAAMAyAhYAAIBlBCwAAADLCFgAAACWEbAAAAAsI2ABAABYRsACAACwLK4DVmVlpb7xjW8oPT1d\
# 2dnZuvvuu7Vv376wPsXFxXIcJ2ybPn16lCoGAADxIK4D1saNG/XII4+opqZGVVVVam9vV0lJiVpa\
# WsL6lZeXq6Ghwd1effXVKFUMAADiQXK0C+hL69atC9t//fXXlZ2drdraWt1yyy3u8f79+8vn80W6\
# PAAAEKfiegbriwKBgCQpMzMz7PiyZcuUlZWl4cOHa8GCBWpqaopGeQAAIE7E9QzWuYwxmjdvnm6+\
# +WYVFha6x2fOnKmCggL5fD7t2bNHFRUVev/991VVVdXt44RCIYVCIXc/GAz2ee0AACC2JEzAmj17\
# tv7whz9o8+bNYcfLy8vdnwsLCzVs2DCNHj1aO3bsUFFRUZfHqays1OLFi/u8XgAAELsS4hbhnDlz\
# 9Jvf/EYbNmzQkCFDztu3qKhIKSkpqqur67a9oqJCgUDA3Q4dOtQXJQMAgBgW1zNYx

# %% [markdown]
# Linking should make it so that particles are remembered. It adds a label 'particle' and these are all unique. As you can see, for the movie it still finds less than 50 particles (Still, one lands over the other, trackpy doesn't find it)

# %%
f_3 = trackpy.batch(movie[:,:,:], 7, minmass=10, invert=False, processes='auto')
t = trackpy.link(f_3, 5, memory=3)
print(t['particle'].nunique())
# Out:
# Frame 99: 45 trajectories present.
# 45

# %% [markdown]
# Now look at the moving average corrected one:

# %%
print(movie.shape)
print(BGCMA.shape)
f_4 = trackpy.batch(BGCMA[:,:,:], 7, minmass=10, invert=False, processes='auto')
#f_4.head

#t2 = trackpy.link(f_4, 5, memory=3)
#print(t2['particle'].nunique())
# Out:
# Frame 86: 0 features
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\sjoer\Anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\sjoer\Anaconda3\lib\site-packages\trackpy\feature.py", line 399, in locate
#     engine=engine, characterize=characterize)
#   File "C:\Users\sjoer\Anaconda3\lib\site-packages\trackpy\refine\center_of_mass.py", line 89, in refine_com
#     return pd.DataFrame(columns=columns)
#   File "C:\Users\sjoer\Anaconda3\lib\site-packages\pandas\core\frame.py", line 348, in __init__
#     mgr = self._init_dict(data, index, columns, dtype=dtype)
#   File "C:\Users\sjoer\Anaconda3\lib\site-packages\pandas\core\frame.py", line 451, in _init_dict
#     nan_dtype)
#   File "C:\Users\sjoer\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py", line 1196, in construct_1d_arraylike_from_scalar
#     dtype = dtype.dtype
# AttributeError: type object 'object' has no attribute 'dtype'
# """
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-801f9446fb14> in <module>()
#       1 print(movie.shape)
#       2 print(BGCMA.shape)
# ----> 3 f_4 = trackpy.batch(BGCMA, 7, minmass=10, invert=False, processes='auto')
#       4 #f_4.head
#       5
#
# ~\Anaconda3\lib\site-packages\trackpy\feature.py in batch(frames, diameter, output, meta, processes, after_locate, **kwargs)
#     555     try:
#     556         all_features = []
# --> 557         for i, features in enumerate(map_func(curried_locate, frames)):
#     558             image = frames[i]
#     559             if hasattr(image, 'frame_no') and image.frame_no is not None:
#
# ~\Anaconda3\lib\multiprocessing\pool.py in next(self, timeout)
#     746         if success:
#     747             return value
# --> 748         raise value
#     749
#     750     __next__ = next                    # XXX
#
# AttributeError: type object 'object' has no attribute 'dtype'

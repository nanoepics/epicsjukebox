# %% [markdown]
# In this notebook, I'll look even deeper into the moving average

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import time

from Particledrop import Landing_Flashes

import trackpy

# %%
nf = 100
fov=[200,300]
meas = Landing_Flashes(fov=fov, seed=500, numpar = 50, noise = 0, nframes = nf, signal = 20, sizevar=0.2, dark = 5, psize = 4, unevenIllumination = False)

print(np.shape(plis))
# Out:
# (29, 3)

# %%
testframe = nf-1
meas.noise = 10
plis = meas.parlist
movie = meas.genStack()

plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

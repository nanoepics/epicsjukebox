# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import time

from Particledrop import Landing_Flashes

import trackpy

np.random.seed(31415)
plt.close('all')

nf = 50
fov=[200,300]
meas = Landing_Flashes(fov=fov, seed=500, numpar = 30, noise = 0, nframes = nf, signal = 20, sizevar=0.2, dark = 5, psize = 4, unevenIllumination = False)
plis = meas.parlist
movie = meas.genStack()
print(np.shape(plis))
# Out:
# (30, 3)

# %%
plt.figure()
plt.title('Simulated Size histogram')
plt.hist(plis[:,2])
plt.show()

# %%
testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

# %%
meas.noise = 1 
plis = meas.parlist
movie = meas.genStack()

testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

# %%
meas.noise = 2 
plis = meas.parlist
movie = meas.genStack()

testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

# %%
img = movie[testframe]
imglist = img.flatten()

fig, ax = plt.subplots()
plt.title('Intensities in last frame')
ax.hist(imglist, bins = 30)
# Out:
# (array([7.8660e+03, 1.5730e+04, 1.5755e+04, 1.0573e+04, 5.2360e+03,
#         2.0870e+03, 7.0700e+02, 2.2100e+02, 1.1700e+02, 1.2600e+02,
#         1.5100e+02, 2.1100e+02, 2.1300e+02, 1.8500e+02, 1.6300e+02,
#         1.3800e+02, 1.1900e+02, 9.3000e+01, 7.5000e+01, 6.5000e+01,
#         4.5000e+01, 2.6000e+01, 2.5000e+01, 3.2000e+01, 2.3000e+01,
#         1.1000e+01, 3.0000e+00, 1.0000e+00, 2.0000e+00, 1.0000e+00]),
#  array([ 5.        ,  5.96176787,  6.92353573,  7.8853036 ,  8.84707146,
#          9.80883933, 10.77060719, 11.73237506, 12.69414293, 13.65591079,
#         14.61767866, 15.57944652, 16.54121439, 17.50298225, 18.46475012,
#         19.42651799, 20.38828585, 21.35005372, 22.31182158, 23.27358945,
#         24.23535731, 25.19712518, 26.15889304, 27.12066091, 28.08242878,
#         29.04419664, 30.00596451, 30.96773237, 31.92950024, 32.8912681 ,
#         33.85303597]),
#  <a list of 30 Patch objects>)

# %%
cutoff = 13 

movie_cutoff = np.where(movie < cutoff, 0, movie)
img_co = movie_cutoff[testframe]

plt.figure()
plt.imshow(img_co)

f = trackpy.locate(movie_cutoff[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie_cutoff[testframe]);

# %%
meas.noise = 5 
plis = meas.parlist
movie = meas.genStack()

testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

# %%
img = movie[testframe]
imglist = img.flatten()

fig, ax = plt.subplots()
plt.title('Intensities in last frame')
ax.hist(imglist, bins = 30)
# Out:
# (array([2.3610e+03, 4.9660e+03, 8.1670e+03, 1.0193e+04, 1.0177e+04,
#         8.4460e+03, 6.1030e+03, 3.7910e+03, 2.1970e+03, 1.0580e+03,
#         5.9700e+02, 3.6800e+02, 2.5100e+02, 2.2000e+02, 1.9900e+02,
#         1.7300e+02, 1.6700e+02, 1.2700e+02, 1.2600e+02, 8.5000e+01,
#         5.8000e+01, 4.9000e+01, 3.2000e+01, 2.1000e+01, 2.9000e+01,
#         2.0000e+01, 8.0000e+00, 5.0000e+00, 5.0000e+00, 1.0000e+00]),
#  array([ 5.        ,  6.07540109,  7.15080218,  8.22620327,  9.30160436,
#         10.37700545, 11.45240654, 12.52780764, 13.60320873, 14.67860982,
#         15.75401091, 16.829412  , 17.90481309, 18.98021418, 20.05561527,
#         21.13101636, 22.20641745, 23.28181854, 24.35721963, 25.43262072,
#         26.50802182, 27.58342291, 28.658824  , 29.73422509, 30.80962618,
#         31.88502727, 32.96042836, 34.03582945, 35.11123054, 36.18663163,
#         37.26203272]),
#  <a list of 30 Patch objects>)

# %%
cutoff = 23

movie_cutoff = np.where(movie < cutoff, 0, movie)
img_co = movie_cutoff[testframe]

plt.figure()
plt.imshow(img_co)

f = trackpy.locate(movie_cutoff[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie_cutoff[testframe]);

# %%
meas.noise = 10 
plis = meas.parlist
movie = meas.genStack()

testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

# %%
img = movie[testframe]
imglist = img.flatten()

fig, ax = plt.subplots()
plt.title('Intensities in last frame')
ax.hist(imglist, bins = 30)
# Out:
# (array([3.4000e+01, 1.4600e+02, 4.0100e+02, 3.3050e+03, 3.6100e+03,
#         5.2220e+03, 1.3934e+04, 7.4110e+03, 6.7040e+03, 9.6430e+03,
#         3.0330e+03, 2.0760e+03, 1.4480e+03, 1.3250e+03, 3.9300e+02,
#         3.0200e+02, 2.6900e+02, 1.6000e+02, 1.5600e+02, 1.1500e+02,
#         9.1000e+01, 7.0000e+01, 5.7000e+01, 3.3000e+01, 2.8000e+01,
#         1.7000e+01, 8.0000e+00, 5.0000e+00, 2.0000e+00, 2.0000e+00]),
#  array([ 5.        ,  6.3066194 ,  7.61323881,  8.91985821, 10.22647762,
#         11.53309702, 12.83971643, 14.14633583, 15.45295524, 16.75957464,
#         18.06619405, 19.37281345, 20.67943286, 21.98605226, 23.29267167,
#         24.59929107, 25.90591048, 27.21252988, 28.51914929, 29.82576869,
#         31.1323881 , 32.4390075 , 33.74562691, 35.05224631, 36.35886572,
#         37.66548512, 38.97210453, 40.27872393, 41.58534334, 42.89196274,
#         44.19858215]),
#  <a list of 30 Patch objects>)

# %%
cutoff = 30

movie_cutoff = np.where(movie < cutoff, 0, movie)
img_co = movie_cutoff[testframe]

plt.figure()
plt.imshow(img_co)

f = trackpy.locate(movie_cutoff[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie_cutoff[testframe]);

# %%
meas.noise = 20 
plis = meas.parlist
movie = meas.genStack()

testframe = nf-1
plt.figure()
plt.imshow(movie[testframe])

f = trackpy.locate(movie[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie[testframe]);

# %%
img = movie[testframe]
imglist = img.flatten()

fig, ax = plt.subplots()
plt.title('Intensities in last frame')
ax.hist(imglist, bins = 30)
# Out:
# (array([2.0000e+00, 1.5000e+01, 2.6000e+01, 2.3600e+02, 8.8900e+02,
#         1.0270e+03, 3.8030e+03, 2.9770e+03, 8.2630e+03, 1.0169e+04,
#         5.0450e+03, 9.4830e+03, 7.2960e+03, 2.6910e+03, 3.7650e+03,
#         1.2250e+03, 1.3620e+03, 6.6700e+02, 3.0800e+02, 2.4600e+02,
#         1.6000e+02, 1.3300e+02, 7.4000e+01, 5.8000e+01, 4.3000e+01,
#         1.5000e+01, 1.4000e+01, 5.0000e+00, 0.0000e+00, 3.0000e+00]),
#  array([ 8.        ,  9.62280916, 11.24561831, 12.86842747, 14.49123662,
#         16.11404578, 17.73685493, 19.35966409, 20.98247324, 22.6052824 ,
#         24.22809155, 25.85090071, 27.47370986, 29.09651902, 30.71932817,
#         32.34213733, 33.96494648, 35.58775564, 37.21056479, 38.83337395,
#         40.4561831 , 42.07899226, 43.70180141, 45.32461057, 46.94741972,
#         48.57022888, 50.19303803, 51.81584719, 53.43865635, 55.0614655 ,
#         56.68427466]),
#  <a list of 30 Patch objects>)

# %%
cutoff = 45

movie_cutoff = np.where(movie < cutoff, 0, movie)
img_co = movie_cutoff[testframe]

plt.figure()
plt.imshow(img_co)

f = trackpy.locate(movie_cutoff[testframe], 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, movie_cutoff[testframe]);

# %%
meas.noise = 0
plis = meas.parlist
movie = meas.genStack()
img = movie[testframe]

plt.figure()
plt.imshow(img)

# %%
from scipy import fftpack
im_fft = fftpack.fft2(img)

# Show the results

def plot_spectrum(im_fft):
    from matplotlib.colors import LogNorm
    # A logarithmic colormap
    plt.imshow(np.abs(im_fft), norm=LogNorm(vmin=5))
    plt.colorbar()

plt.figure()
plot_spectrum(im_fft)
plt.title('Fourier transform')
# Out:
# C:\Users\sjoer\Anaconda3\lib\site-packages\scipy\fftpack\basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x
# Text(0.5,1,'Fourier transform')

# %%
meas.noise = 20
plis = meas.parlist
movie = meas.genStack()
img = movie[testframe]

plt.figure()
plt.imshow(img)

# %%
from scipy import fftpack
im_fft = fftpack.fft2(img)

# Show the results

def plot_spectrum(im_fft):
    from matplotlib.colors import LogNorm
    # A logarithmic colormap
    plt.imshow(np.abs(im_fft), norm=LogNorm(vmin=5))
    plt.colorbar()

plt.figure()
plot_spectrum(im_fft)
plt.title('Fourier transform')
# Out:
# C:\Users\sjoer\Anaconda3\lib\site-packages\scipy\fftpack\basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x
# Text(0.5,1,'Fourier transform')

# %% [markdown]
# The corners contain the real info (particles), the rest is noise. How to compare to particle size?

# %%
# In the lines following, we'll make a copy of the original spectrum and
# truncate coefficients.

# Define the fraction of coefficients (in each direction) we keep
keep_fraction = 0.05

# Call ff a copy of the original transform. Numpy arrays have a copy
# method for this purpose.
im_fft2 = im_fft.copy()

# Set r and c to be the number of rows and columns of the array.
r, c = im_fft2.shape

# Set to zero all rows with indices between r*keep_fraction and
# r*(1-keep_fraction):
im_fft2[int(r*keep_fraction):int(r*(1-keep_fraction))] = 0

# Similarly with the columns:
im_fft2[:, int(c*keep_fraction):int(c*(1-keep_fraction))] = 0

plt.figure()
plot_spectrum(im_fft2)
plt.title('Filtered Spectrum')
# Out:
# Text(0.5,1,'Filtered Spectrum')

# %%
# Reconstruct the denoised image from the filtered spectrum, keep only the
# real part for display.
im_new = fftpack.ifft2(im_fft2).real

plt.figure()
plt.imshow(im_new, plt.cm.gray)
plt.title('Reconstructed Image')
# Out:
# C:\Users\sjoer\Anaconda3\lib\site-packages\scipy\fftpack\basic.py:160: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x
# Text(0.5,1,'Reconstructed Image')

# %%
f = trackpy.locate(im_new, 7, minmass = 10, invert = False)

fig, ax = plt.subplots()
plt.title('Found Size Histogram')
ax.hist(f['mass'])

# Optionally, label the axes.
ax.set(xlabel='mass', ylabel='count');
plt.figure()
trackpy.annotate(f, im_new);
